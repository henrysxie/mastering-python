# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/sales-funnel.csv')

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
len(df[(df['Price'] > 8000) | (df['Status'] == 'pending')])
# Out:
# 15

# %%
df.groupby('Rep').apply(
    lambda group: (
        group['Price'] * group['Quantity']
    ).sum()
)
# Out:
# Rep
# Cedric Moss      175000
# Craig Booker      85000
# Daniel Hilton    220000
# John Smith        45000
# Wendy Yule       661000
# dtype: int64

# %%
df['Sales'] = df['Quantity'] * df['Price']

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
df['Sales'].sum()
# Out:
# 1186000

# %%
df[df['Status'] == 'won']['Sales'].sum()
# Out:
# 781000

# %%
df[df['Status'] == 'won'].groupby('Manager')['Sales'].sum()
# Out:
# Manager
# Debra Henley     130000
# Fred Anderson    651000
# Name: Sales, dtype: int64

# %%
won_deals = df[df['Status'] == 'won']

# %%
df['Date'] = pd.date_range('2016-06-01', periods=len(df))

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
df[(df['Date'] > '6/10/2016') & (df['Status'] == 'won')]
# Out:
#     Account                         Name         Rep        Manager  \
# 13   307599  Kassulke, Ondricka and Metz  Wendy Yule  Fred Anderson
# 14   688981                  Keeling LLC  Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price Status   Sales       Date
# 13  Maintenance         3    7000    won   21000 2016-06-14
# 14          CPU         5  100000    won  500000 2016-06-15

# %%
date_df = df.set_index('Date')

# %%
date_df["2016-06-14":]
# Out:
#             Account                         Name         Rep        Manager  \
# Date
# 2016-06-14   307599  Kassulke, Ondricka and Metz  Wendy Yule  Fred Anderson
# 2016-06-15   688981                  Keeling LLC  Wendy Yule  Fred Anderson
# 2016-06-16   729833                    Koepp Ltd  Wendy Yule  Fred Anderson
# 2016-06-17   729833                    Koepp Ltd  Wendy Yule  Fred Anderson
#
#                 Product  Quantity   Price     Status   Sales
# Date
# 2016-06-14  Maintenance         3    7000        won   21000
# 2016-06-15          CPU         5  100000        won  500000
# 2016-06-16          CPU         2   65000   declined  130000
# 2016-06-17      Monitor         2    5000  presented   10000

# %%
df.pivot_table(['Sales', 'Quantity'],
               index=['Manager', 'Rep'],
               columns='Status')
# Out:
#                                Sales                           Quantity  \
# Status                      declined pending presented     won declined
# Manager       Rep
# Debra Henley  Craig Booker     35000   10000     20000     NaN        1
#               Daniel Hilton      NaN   80000     10000  130000      NaN
#               John Smith       35000   10000       NaN     NaN        1
# Fred Anderson Cedric Moss        NaN    5000     20000  130000      NaN
#               Wendy Yule      130000     NaN     10000  260500        2
#
#
# Status                      pending presented won
# Manager       Rep
# Debra Henley  Craig Booker        2         1 NaN
#               Daniel Hilton       2         1   2
#               John Smith          2       NaN NaN
# Fred Anderson Cedric Moss         1         1   2
#               Wendy Yule        NaN         2   4
