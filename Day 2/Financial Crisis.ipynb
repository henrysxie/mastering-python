# %%
import datetime
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Plots reside inside figures
fig = plt.figure()

# 1x1 plots in the figure
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('../data/spx.csv', index_col=0, parse_dates=True)

spx = data['SPX']

spx.plot(ax=ax, style='k-', figsize=(15,9))

# Important Events
crisis_data = [
    (datetime.datetime(2007, 10, 11), 'Peak of the Bull Market'),
    (datetime.datetime(2008, 3, 12), 'Bear Stearns Collapsed'),
    (datetime.datetime(2008, 9, 15), 'Lehman Bankruptcy'),
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 20),
               xytext=(date, spx.asof(date) + 150),
               arrowprops=dict(facecolor='red'),
               horizontalalignment='left',
               verticalalignment='top')

# Zoom in on dates we want to look at
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important Events in 2008-09 Financial Crisis')

# %%
spx = data['SPX']

spx.plot(ax=ax, style='k-', figsize=(15,9))

# %%
import pandas.io.data as web

# %%
credit_suisse = web.DataReader("CS", 'yahoo', datetime.datetime(2016, 1, 1), datetime.datetime(2016, 6, 1))

# %%
credit_suisse['Close'].plot()
